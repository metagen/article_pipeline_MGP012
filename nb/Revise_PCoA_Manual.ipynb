# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /Users/nsmt/miniconda3/envs/bitools_py3_env/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv("../data_output/pcoa/co.bc.mds.del_label.tsv", sep="\t", index_col=0)

# %%
df = pd.read_csv("../data_output/pcoa/co.bc.mds.del_label.tsv", sep="\t", index_col=0)

sns.set(style='whitegrid', color_codes=True)
plt.figure(figsize=(8, 6))
plt.scatter(df["PC1"], df["PC2"], c=df["color"], edgecolors="gray")

for subject_id in subject_ids:
    xs = df.loc[f"{subject_id}_0w", "PC1"]
    ys = df.loc[f"{subject_id}_0w", "PC2"]
    xe = df.loc[f"{subject_id}_4w", "PC1"]
    ye = df.loc[f"{subject_id}_4w", "PC2"]
    plt.arrow(xs, ys, (xe-xs), (ye-ys), head_width=0.01, head_length=0.02, fc="gray", ec="gray")

plt.title("Metabolome(Bray-Curtis distance)")
plt.savefig("../data_output/pcoa/co.bc.mds.del_label.arrow.pdf")

# %%
df = pd.read_csv("../data_output/pcoa/wu.tsv.mds.del_label.tsv", sep="\t", index_col=0)

sns.set(style='whitegrid', color_codes=True)
plt.figure(figsize=(8, 6))
plt.scatter(df["PC1"], df["PC2"], c=df["color"], edgecolors="gray")

for subject_id in subject_ids:
    xs = df.loc[f"{subject_id}_0w", "PC1"]
    ys = df.loc[f"{subject_id}_0w", "PC2"]
    xe = df.loc[f"{subject_id}_4w", "PC1"]
    ye = df.loc[f"{subject_id}_4w", "PC2"]
    plt.arrow(xs, ys, (xe-xs), (ye-ys), head_width=0.01, head_length=0.02, fc="gray", ec="gray")

plt.title("Metabolome(Bray-Curtis distance)")
plt.savefig("../data_output/pcoa/wu.tsv.mds.del_label.arrow.pdf")
